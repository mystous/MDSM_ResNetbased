# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
log_path = '2023-02-27_171008'
hyperparameter_name = 'model-ResNet18_epochs-1000-batch-512-randomsplit-True-2023-02-27_171008'
df = pd.read_csv(f'results/{log_path}/training_metrics/amazon_hmdvr_df_tokenized_sentiment_score_{hyperparameter_name}.csv')
graph_title = hyperparameter_name

# %%
df
# Out:
#      validation_mae  validation_mse  validation_rmse  validation_mape  \
# 0          1.158022        3.824083         1.955526        86.776360
# 1          1.095541        3.567486         1.888779        79.508140
# 2          1.028814        3.324841         1.823415        65.840660
# 3          0.976949        3.113437         1.764493        67.306640
# 4          0.968456        3.082499         1.755705        67.016480
# ..              ...             ...              ...              ...
# 995        0.989991        3.017288         1.737034        61.210190
# 996        0.975432        2.985745         1.727931        60.462536
# 997        0.982408        3.011526         1.735375        60.401882
# 998        0.976342        2.994540         1.730474        59.900917
# 999        0.971186        2.964513         1.721776        59.928722
#
#      validation_mbe  validation_accuracy  train_mae  train_mse  train_rmse  \
# 0          1.054898            57.294510   1.251668   4.119578    2.029675
# 1          0.903245            58.871700   1.209964   4.036472    2.009097
# 2          0.570822            60.752197   1.038899   3.353731    1.831319
# 3          0.702760            61.662117   0.977859   3.110858    1.763763
# 4          0.733091            61.904762   0.967015   3.064377    1.750536
# ..              ...                  ...        ...        ...         ...
# 995        0.444040            58.295420   0.643236   2.110327    1.452697
# 996        0.452533            59.144676   0.637549   2.096451    1.447913
# 997        0.440097            58.871700   0.647786   2.134137    1.460869
# 998        0.435244            58.993023   0.637398   2.090992    1.446026
# 999        0.438580            58.993023   0.639369   2.098271    1.448541
#
#      train_mape  train_mbe  train_accuracy
# 0     86.319890   0.875265       53.738247
# 1     83.794100   0.867076       56.126780
# 2     70.626205   0.729982       60.077343
# 3     63.453014   0.594783       61.449802
# 4     63.144910   0.606991       61.540794
# ..          ...        ...             ...
# 995   45.477580   0.462314       75.697600
# 996   45.225708   0.464210       76.000910
# 997   45.995853   0.473688       75.682440
# 998   45.141796   0.463603       75.925080
# 999   45.099583   0.459964       75.826510
#
# [1000 rows x 12 columns]

# %%
df[['train_mae', 'validation_mae']].plot()
plt.title("Mean Abs Error [STR] : {}".format(graph_title))
plt.ylabel("Mean Abs Error [STR]")
plt.xlabel("Training Epochs")
plt.ylim([0,1.5])
plt.legend()
plt.show()

df[['train_mse', 'validation_mse']].plot()
plt.title("Mean Square Error [$STR^2$] : {}".format(graph_title))
plt.ylabel("Mean Square Error [$STR^2$] ")
plt.xlabel("Training Epochs")
plt.ylim([0,5])
plt.legend()
plt.show()

df[['train_rmse', 'validation_rmse']].plot()
plt.title("Root Mean Squared Error: {}".format(graph_title))
plt.ylabel("Root Mean Squared Error")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

df[['train_mape', 'validation_mape']].plot()
plt.title("Mean Absolute Percentage Error : {}".format(graph_title))
plt.ylabel("Mean Absolute Percentage Error(%)")
plt.xlabel("Training Epochs")
plt.ylim([0,100])
plt.legend()
plt.show()

df[['train_mbe', 'validation_mbe']].plot()
plt.title("Mean Bias Error : {}".format(graph_title))
plt.ylabel("Mean Bias Error")
plt.xlabel("Training Epochs")
plt.ylim([0,1.5])
plt.legend()
plt.show()

df[['train_accuracy', 'validation_accuracy']].plot()
plt.title("Train Accuracy : {}".format(graph_title))
#plt.plot(range(1,EPOCHS+1),mse_history["val"],label="validation mse")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
#plt.ylim([0,1.5])
plt.legend()
plt.show()
