# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
log_path = '2023-02-26_000157'
hyperparameter_name = 'model-ResNet18_epochs-40-batch-512-randomsplit-True-2023-02-26_000157'
df = pd.read_csv(f'results/{log_path}/training_metrics/amazon_hmdvr_df_tokenized_sentiment_score_{hyperparameter_name}.csv')
graph_title = hyperparameter_name

# %%
df
# Out:
#     validation_mae  validation_mse  validation_rmse  validation_mape  \
# 0         1.154686        3.820746         1.954673        88.845920
# 1         1.168942        3.855626         1.963575        88.788800
# 2         1.153169        3.808311         1.951489        88.679600
# 3         1.117683        3.658781         1.912794        77.779800
# 4         1.035487        3.333333         1.825742        64.544040
# 5         1.018805        3.269942         1.808298        66.087350
# 6         1.000303        3.195632         1.787633        62.451214
# 7         0.989688        3.160146         1.777680        66.995760
# 8         0.986351        3.135578         1.770756        65.692550
# 9         0.996360        3.191083         1.786360        62.449707
# 10        0.983925        3.136185         1.770927        64.762910
# 11        1.028814        3.313922         1.820418        57.096355
# 12        0.960267        3.031847         1.741220        65.640470
# 13        0.954504        3.018198         1.737296        62.911736
# 14        0.994844        3.154990         1.776229        58.416740
# 15        0.966940        3.065817         1.750948        64.406020
# 16        0.973309        3.086139         1.756741        62.353146
# 17        0.977252        3.107674         1.762860        61.538773
# 18        0.978769        3.097665         1.760018        59.673435
# 19        0.952078        2.999394         1.731876        63.105350
# 20        0.983015        3.131635         1.769643        60.134464
# 21        0.958144        3.019412         1.737645        65.537350
# 22        0.974826        3.099788         1.760621        60.230003
# 23        0.993327        3.176524         1.782281        59.501570
# 24        0.985441        3.135881         1.770842        60.878075
# 25        0.969973        3.070670         1.752333        63.624510
# 26        0.952988        3.011829         1.735462        62.638260
# 27        0.970579        3.073703         1.753198        57.994640
# 28        0.961480        3.030027         1.740697        61.040848
# 29        0.948135        2.997877         1.731438        62.267216
# 30        0.947528        2.974826         1.724768        63.045700
# 31        0.972096        3.089779         1.757777        64.117890
# 32        0.963300        3.043373         1.744527        62.142860
# 33        0.976039        3.097968         1.760104        60.689514
# 34        0.968456        3.074613         1.753457        64.363570
# 35        0.962087        3.042160         1.744179        61.410880
# 36        0.965120        3.054899         1.747827        65.812860
# 37        0.969063        3.072187         1.752765        58.886360
# 38        0.964210        3.051562         1.746872        60.520164
# 39        0.959660        3.020928         1.738082        61.739456
#
#     validation_mbe  validation_accuracy  train_mae  train_mse  train_rmse  \
# 0         1.154686            57.476494   1.294662   4.297543    2.073052
# 1         1.116773            56.960873   1.143691   3.770625    1.941810
# 2         1.151350            57.415833   1.139672   3.758417    1.938664
# 3         0.807704            57.840460   1.115560   3.663785    1.914102
# 4         0.521080            59.751290   1.047467   3.392478    1.841868
# 5         0.606915            60.357903   0.982181   3.132772    1.769964
# 6         0.525933            60.630875   0.972475   3.090764    1.758057
# 7         0.681529            61.025173   0.961101   3.046027    1.745287
# 8         0.661207            60.873520   0.959509   3.042160    1.744179
# 9         0.518350            61.025173   0.952078   3.010616    1.735113
# 10        0.621171            61.146496   0.944419   2.981574    1.726724
# 11        0.299666            59.993935   0.943433   2.974522    1.724680
# 12        0.697604            61.571125   0.933197   2.935927    1.713455
# 13        0.617228            61.753110   0.927358   2.904914    1.704381
# 14        0.383379            60.297240   0.922809   2.896269    1.701843
# 15        0.631483            61.510464   0.924856   2.900743    1.703157
# 16        0.566879            61.176826   0.931908   2.934334    1.712990
# 17        0.527146            61.298150   0.910146   2.847968    1.687592
# 18        0.465575            60.964510   0.923794   2.900136    1.702979
# 19        0.603882            61.722780   0.918866   2.879891    1.697024
# 20        0.459509            61.298150   0.919472   2.880649    1.697248
# 21        0.701547            61.480133   0.916060   2.870261    1.694184
# 22        0.499848            61.358810   0.914240   2.861617    1.691631
# 23        0.427358            61.116165   0.916212   2.869351    1.693916
# 24        0.488626            61.055504   0.902260   2.817031    1.678401
# 25        0.601759            61.328480   0.905520   2.832727    1.683071
# 26        0.592053            61.783440   0.910525   2.847892    1.687570
# 27        0.411283            61.298150   0.897938   2.795875    1.672087
# 28        0.535032            61.419470   0.902260   2.814453    1.677633
# 29        0.598726            62.147408   0.897103   2.789733    1.670249
# 30        0.615711            61.631786   0.898696   2.800728    1.673537
# 31        0.608129            61.389140   0.907567   2.833713    1.683363
# 32        0.552017            61.389140   0.909691   2.839930    1.685209
# 33        0.502275            61.267820   0.885805   2.751592    1.658792
# 34        0.611162            61.540794   0.895739   2.788823    1.669977
# 35        0.535032            61.571125   0.901274   2.808766    1.675937
# 36        0.697604            61.631786   0.885957   2.749773    1.658244
# 37        0.460115            61.389140   0.881180   2.738626    1.654880
# 38        0.509857            61.631786   0.893767   2.785487    1.668978
# 39        0.540491            61.449802   0.881938   2.737868    1.654650
#
#     train_mape  train_mbe  train_accuracy
# 0    83.702484   0.709736       52.964817
# 1    87.248250   1.117759       57.666060
# 2    87.263040   1.126327       57.840460
# 3    82.837430   1.012436       58.454655
# 4    71.316860   0.737185       59.925690
# 5    64.967270   0.651274       61.555960
# 6    63.066936   0.593646       61.578710
# 7    61.404945   0.575902       61.897180
# 8    61.732260   0.583257       62.003338
# 9    62.211483   0.609797       62.071580
# 10   61.181250   0.595769       62.299060
# 11   61.281715   0.597513       62.306640
# 12   59.747250   0.561799       62.481045
# 13   59.977757   0.583864       62.556870
# 14   58.941208   0.565059       62.845010
# 15   59.646393   0.572566       62.617530
# 16   60.120815   0.577191       62.647860
# 17   59.184742   0.584395       63.019413
# 18   59.692520   0.586366       62.822260
# 19   59.165657   0.564301       62.784348
# 20   59.450638   0.586139       62.882923
# 21   59.210896   0.570898       63.004246
# 22   58.609726   0.558311       62.966330
# 23   59.997210   0.605323       62.928420
# 24   58.163864   0.570898       63.299970
# 25   58.252453   0.561723       63.262054
# 26   58.235520   0.560661       63.042160
# 27   58.473236   0.581286       63.246890
# 28   57.804565   0.552548       63.171066
# 29   57.261013   0.548605       63.208977
# 30   57.190884   0.532909       63.231724
# 31   58.204050   0.555732       63.026993
# 32   58.630573   0.562254       62.875340
# 33   57.034810   0.547012       63.633606
# 34   57.005737   0.533136       63.224144
# 35   57.932465   0.559448       63.224144
# 36   57.105072   0.552624       63.572945
# 37   57.009410   0.557856       63.792843
# 38   57.087630   0.532833       63.459206
# 39   56.148136   0.531165       63.648773

# %%
df[['train_mae', 'validation_mae']].plot()
plt.title("Mean Abs Error [STR] : {}".format(graph_title))
plt.ylabel("Mean Abs Error [STR]")
plt.xlabel("Training Epochs")
plt.ylim([0,1.5])
plt.legend()
plt.show()

df[['train_mse', 'validation_mse']].plot()
plt.title("Mean Square Error [$STR^2$] : {}".format(graph_title))
plt.ylabel("Mean Square Error [$STR^2$] ")
plt.xlabel("Training Epochs")
plt.ylim([0,5])
plt.legend()
plt.show()

df[['train_rmse', 'validation_rmse']].plot()
plt.title("Root Mean Squared Error: {}".format(graph_title))
plt.ylabel("Root Mean Squared Error")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

df[['train_mape', 'validation_mape']].plot()
plt.title("Mean Absolute Percentage Error : {}".format(graph_title))
plt.ylabel("Mean Absolute Percentage Error(%)")
plt.xlabel("Training Epochs")
plt.ylim([0,100])
plt.legend()
plt.show()

df[['train_mbe', 'validation_mbe']].plot()
plt.title("Mean Bias Error : {}".format(graph_title))
plt.ylabel("Mean Bias Error")
plt.xlabel("Training Epochs")
plt.ylim([0,1.5])
plt.legend()
plt.show()

df[['train_accuracy', 'validation_accuracy']].plot()
plt.title("Train Accuracy : {}".format(graph_title))
#plt.plot(range(1,EPOCHS+1),mse_history["val"],label="validation mse")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
#plt.ylim([0,1.5])
plt.legend()
plt.show()
